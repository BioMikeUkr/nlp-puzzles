# %% [markdown]
# # Task 1: Fine-tune Sentence Transformer
#
# Fine-tune a model on domain-specific data and measure improvements.
#
# **Goals:**
# - Prepare training data
# - Fine-tune with MultipleNegativesRankingLoss
# - Evaluate improvements
# - Compare before/after performance

# %%
from sentence_transformers import SentenceTransformer, InputExample, losses
from torch.utils.data import DataLoader
import json
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Load Data

# %%
with open('../fixtures/input/training_pairs_hard.json', 'r') as f:
    training_data = json.load(f)

print(f"Loaded {len(training_data)} training pairs")

# %% [markdown]
# ## Task 1: Prepare Training Examples

# %%
# YOUR CODE HERE
# Create list of InputExample objects
# Use query and positive text from each training pair

train_examples = []  # TODO: Create InputExample list

# TEST
assert len(train_examples) > 0, "No training examples created"
assert isinstance(train_examples[0], InputExample), "Wrong type"
print("✓ Task 1 passed")

# %% [markdown]
# ## Task 2: Create DataLoader

# %%
# YOUR CODE HERE
# Create DataLoader with batch_size=4 and shuffle=True

train_dataloader = None  # TODO: Create DataLoader

# TEST
assert train_dataloader is not None, "DataLoader not created"
assert train_dataloader.batch_size == 4, "Wrong batch size"
print("✓ Task 2 passed")

# %% [markdown]
# ## Task 3: Fine-tune Model

# %%
# YOUR CODE HERE
# 1. Load model 'all-MiniLM-L6-v2'
# 2. Create MultipleNegativesRankingLoss
# 3. Fine-tune for 3 epochs
# 4. Save to '../output/fine_tuned_model'

model = None  # TODO: Load and fine-tune model

# TEST
assert model is not None, "Model not created"
print("✓ Task 3 passed")

# %% [markdown]
# ## Task 4: Compare Performance

# %%
# YOUR CODE HERE
# 1. Load generic model 'all-MiniLM-L6-v2'
# 2. Load fine-tuned model from '../output/fine_tuned_model'
# 3. Test both on first training pair
# 4. Calculate similarity improvement

generic_model = None  # TODO: Load generic model
finetuned_model = None  # TODO: Load fine-tuned model
improvement = 0.0  # TODO: Calculate improvement

# TEST
assert generic_model is not None, "Generic model not loaded"
assert finetuned_model is not None, "Fine-tuned model not loaded"
print(f"Improvement: +{improvement:.3f}")
print("✓ Task 4 passed")

# %% [markdown]
# ## Summary
#
# ✓ Prepared training data
# ✓ Fine-tuned model
# ✓ Measured improvements
